# %% [markdown]
# ## Traffic Delay Quantification Using Parking Violation Records and Spatial Risk Modeling

# %%
import pandas as pd
import numpy as np
import json
import os, glob
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns
import h3

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["font.size"] = 10

print("✓ Libraries loaded")
# Out:
# ✓ Libraries loaded

# %%
df = pd.read_csv('violations_geocoded.csv')
df.columns
# Out:
# Index(['id', 'latitude', 'longitude', 'location', 'vehicle_number',
#        'vehicle_type', 'description', 'violation_type', 'offence_code',
#        'created_datetime', 'closed_datetime', 'modified_datetime', 'device_id',
#        'created_by_id', 'center_code', 'police_station', 'data_sent_to_scita',
#        'junction_name', 'action_taken_timestamp',
#        'data_sent_to_scita_timestamp', 'updated_vehicle_number',
#        'updated_vehicle_type', 'validation_status', 'validation_timestamp',
#        'created_ist', 'hour_ist', 'date', 'day_of_week', 'month',
#        'primary_violation', 'violation_count', 'violation_impact',
#        'vehicle_weight', 'risk_score_raw', 'has_junction', 'lat_valid',
#        'lon_valid', 'geo_valid', 'is_validated', 'h3_cell', 'inferred_area',
#        'junction_resolved'],
#       dtype='object')

# %%
WORKDIR = "."
priority = pd.read_csv("enforcement_priority_ranking.csv")
print(f"✓ Priority list : {len(priority):,} ranked enforcement zones")
# Out:
# ✓ Priority list : 180 ranked enforcement zones

# %%
junction_h3_map = (
    df[
        ["junction_resolved", "h3_cell"]
    ]
    .dropna()
    .drop_duplicates()
    .rename(
        columns={"junction_resolved": "junction_name"}
    )
)

# %%
priority = priority.merge(
    junction_h3_map,
    on="junction_name",
    how="left"
)

# %%
priority.columns
# Out:
# Index(['priority_rank', 'junction_name', 'n_violations', 'total_risk', 'cii',
#        'cii_tier', 'dominant_type', 'dominant_vehicle', 'dominant_station',
#        'lat', 'lon', 'h3_cell'],
#       dtype='object')

# %%
df[['created_ist','hour_ist']].head()
# Out:
#            created_ist  hour_ist
# 0  2023-11-20 05:58:46         5
# 1  2023-11-20 05:57:46         5
# 2  2023-11-16 12:17:46        12
# 3  2023-11-22 10:26:46        10
# 4  2023-11-28 12:34:46        12

# %%
df_overlap = df.copy()

df_overlap["created_ist"] = pd.to_datetime(
    df_overlap["created_ist"]
)

df_overlap["end_time"] = (
    df_overlap["created_ist"]
    + pd.Timedelta(minutes=20)
)

# %%
from collections import defaultdict

df_overlap["active_violations"] = 1

for (junction, date), idx in (
    df_overlap
    .groupby(["junction_resolved", "date"])
    .groups.items()
):

    grp = (
        df_overlap.loc[idx]
        .sort_values("created_ist")
    )

    starts = grp["created_ist"].values
    ends   = grp["end_time"].values

    active_counts = []

    for i in range(len(grp)):

        current_start = starts[i]

        overlap_count = (
            (starts <= current_start)
            &
            (ends > current_start)
        ).sum()

        active_counts.append(overlap_count)

    df_overlap.loc[
        grp.index,
        "active_violations"
    ] = active_counts

# %%
df_overlap["overlap_multiplier"] = (
    1
    + 0.5
    * (df_overlap["active_violations"] - 1)
)

# %%
df_overlap["risk_score_overlap"] = (
    df_overlap["risk_score_raw"]
    *
    df_overlap["overlap_multiplier"]
)

# %%
overlap_stats = (
    df_overlap
    .groupby("junction_resolved")
    .agg(
        total_overlap_risk=("risk_score_overlap", "sum"),
        avg_active_violations=("active_violations", "mean"),
        max_active_violations=("active_violations", "max"),
        avg_overlap_multiplier=("overlap_multiplier", "mean"),
        max_overlap_multiplier=("overlap_multiplier", "max")
    )
    .reset_index()
)

# %%
overlap_stats = overlap_stats.rename(
    columns={"junction_resolved": "junction_name"}
)

# %%
print(priority.columns)
print(overlap_stats.columns)
# Out:
# Index(['priority_rank', 'junction_name', 'n_violations', 'total_risk', 'cii',
#        'cii_tier', 'dominant_type', 'dominant_vehicle', 'dominant_station',
#        'lat', 'lon', 'h3_cell'],
#       dtype='object')
# Index(['junction_name', 'total_overlap_risk', 'avg_active_violations',
#        'max_active_violations', 'avg_overlap_multiplier',
#        'max_overlap_multiplier'],
#       dtype='object')

# %%
priority = priority.merge(
    overlap_stats,
    on="junction_name",
    how="left"
)

# %%
priority.head()
# Out:
#    priority_rank                   junction_name  n_violations  total_risk  \
# 0              1  BTP051 - Safina Plaza Junction          5887       30130
# 1              1  BTP051 - Safina Plaza Junction          5887       30130
# 2              1  BTP051 - Safina Plaza Junction          5887       30130
# 3              1  BTP051 - Safina Plaza Junction          5887       30130
# 4              1  BTP051 - Safina Plaza Junction          5887       30130
#
#     cii cii_tier  dominant_type dominant_vehicle dominant_station        lat  \
# 0  79.6   SEVERE  WRONG PARKING          SCOOTER     Shivajinagar  12.981904
# 1  79.6   SEVERE  WRONG PARKING          SCOOTER     Shivajinagar  12.981904
# 2  79.6   SEVERE  WRONG PARKING          SCOOTER     Shivajinagar  12.981904
# 3  79.6   SEVERE  WRONG PARKING          SCOOTER     Shivajinagar  12.981904
# 4  79.6   SEVERE  WRONG PARKING          SCOOTER     Shivajinagar  12.981904
#
#          lon          h3_cell  total_overlap_risk  avg_active_violations  \
# 0  77.606975  8861892e9bfffff            312155.0              12.048629
# 1  77.606975  8861892e95fffff            312155.0              12.048629
# 2  77.606975  8861892e91fffff            312155.0              12.048629
# 3  77.606975  88618925a5fffff            312155.0              12.048629
# 4  77.606975  8861892e93fffff            312155.0              12.048629
#
#    max_active_violations  avg_overlap_multiplier  max_overlap_multiplier
# 0                     76                6.524314                    38.5
# 1                     76                6.524314                    38.5
# 2                     76                6.524314                    38.5
# 3                     76                6.524314                    38.5
# 4                     76                6.524314                    38.5

# %%
q50 = priority['cii'].quantile(0.50)
q75 = priority['cii'].quantile(0.75)
q90 = priority['cii'].quantile(0.90)
q99 = priority['cii'].quantile(0.99)



def assign_road_factor(x):
    if x >= q99:
        return 5
    elif x >= q90:
        return 4
    elif x >= q75:
        return 3
    elif x >= q50:
        return 2
    return 1

priority['road_factor'] = priority['cii'].apply(assign_road_factor)

# %%
IMPACT_WEIGHTS = {
    "PARKING IN A MAIN ROAD": 5,
    "PARKING NEAR ROAD CROSSING": 4,
    "PARKING OTHER THAN BUS STOP": 2,
    "PARKING NEAR TRAFFIC LIGHT OR ZEBRA CROSS": 4,
    "PARKING NEAR BUSTOP/SCHOOL/HOSPITAL ETC": 4,
    "DOUBLE PARKING": 3,
    "NO PARKING": 3,
    "WRONG PARKING": 3,
    "PARKING OPPOSITE TO ANOTHER PARKED VEHICLE": 3,
    "PARKING ON FOOTPATH": 2,

    # mild congestion
    "H T V PROHIBITED": 1,

    # no direct congestion effect
    "DEFECTIVE NUMBER PLATE": 0,
    "FAIL TO USE SAFETY BELTS": 0,
    "WITHOUT SIDE MIRROR": 0,
    "OBSTRUCTING DRIVER": 0,
    "DEMANDING EXCESS FARE": 0,
    "REFUSE TO GO FOR HIRE": 0,
}

VEHICLE_WEIGHTS = {
    # Two-wheelers
    "MOTOR CYCLE": 1,
    "SCOOTER": 1,
    "MOPED": 1,

    # Small passenger vehicles
    "PASSENGER AUTO": 2,
    "GOODS AUTO": 2,
    "CAR": 2,
    "JEEP": 2,

    # Medium vehicles
    "MAXI-CAB": 3,
    "VAN": 3,
    "TEMPO": 3,
    "SCHOOL VEHICLE": 3,
    "OTHERS": 3,

    # Large commercial vehicles
    "LGV": 4,
    "MINI LORRY": 4,
    "LORRY/GOODS VEHICLE": 4,
    "TRACTOR": 4,
    "TOURIST BUS": 4,

    # Heavy vehicles
    "HGV": 5,
    "PRIVATE BUS": 5,
    "BUS (BMTC/KSRTC)": 5,
    "FACTORY BUS": 5,
    "TANKER": 5,
    "TRAILER": 5
}

# %%
priority["congestion_weight"] = (
    priority["dominant_type"]
    .map(IMPACT_WEIGHTS)
    .fillna(0)
)

# %%
priority["vehicle_weight"] = (
    priority["dominant_vehicle"]
    .map(VEHICLE_WEIGHTS)
    .fillna(0)
)

# %%
BLOCK_DURATION = 20

priority["delay_score"] = (
    BLOCK_DURATION
    * priority["road_factor"]
    * priority["total_overlap_risk"]
)

# %%
priority["congestion_intensity"] = (
    priority["total_overlap_risk"]
    / priority["n_violations"]
)

# %%
priority["delay_index"] = (
    100
    * priority["delay_score"]
    / priority["delay_score"].max()
)

# %%
priority["vehicle_minutes_lost"] = (
    priority["delay_score"].round()
)

# %%
AVG_OCCUPANCY = 1.5
VALUE_OF_TIME_RS_PER_HR = 250

priority["person_minutes_lost"] = (
    priority["vehicle_minutes_lost"]
    * AVG_OCCUPANCY
)

priority["person_hours_lost"]  = (
    priority["person_minutes_lost"]/60
)

priority["congestion_cost_rs"]  = (
    priority["person_hours_lost"] * VALUE_OF_TIME_RS_PER_HR).round(0)

# %%
q50 = priority["delay_score"].quantile(0.50)
q75 = priority["delay_score"].quantile(0.75)
q90 = priority["delay_score"].quantile(0.90)

priority["traffic_severity"] = pd.cut(
    priority["delay_score"],
    bins=[-np.inf, q50, q75, q90, np.inf],
    labels=[
        "LOW",
        "MEDIUM",
        "HIGH",
        "CRITICAL"
    ]
)

# %%
priority["traffic_impact_score"] = (
      0.50 * (
          priority["delay_score"]
          / priority["delay_score"].max()
      )
    + 0.30 * (
          priority["cii"]
          / priority["cii"].max()
      )
    + 0.20 * (
          priority["n_violations"]
          / priority["n_violations"].max()
      )
)

priority["traffic_impact_score"] *= 100

# %%
priority = priority.sort_values(
    "traffic_impact_score",
    ascending=False
).reset_index(drop=True)

priority["traffic_rank"] = (
    priority.index + 1
)

# %%
cols = [
    "traffic_rank",
    "junction_name",
    "traffic_impact_score",
    "delay_score",
    "vehicle_minutes_lost",
    "person_minutes_lost",
    "n_violations",
    "cii",
    "traffic_severity"
]

priority[cols].head(20)
# Out:
#     traffic_rank                    junction_name  traffic_impact_score  \
# 0              1   BTP051 - Safina Plaza Junction             88.056107
# 1              2   BTP051 - Safina Plaza Junction             88.056107
# 2              3   BTP051 - Safina Plaza Junction             88.056107
# 3              4   BTP051 - Safina Plaza Junction             88.056107
# 4              5   BTP051 - Safina Plaza Junction             88.056107
# 5              6   BTP051 - Safina Plaza Junction             88.056107
# 6              7   BTP051 - Safina Plaza Junction             88.056107
# 7              8   BTP051 - Safina Plaza Junction             88.056107
# 8              9   BTP051 - Safina Plaza Junction             88.056107
# 9             10   BTP051 - Safina Plaza Junction             88.056107
# 10            11   BTP051 - Safina Plaza Junction             88.056107
# 11            12  BTP044 - Sagar Theatre Junction             60.375010
# 12            13  BTP044 - Sagar Theatre Junction             60.375010
# 13            14  BTP044 - Sagar Theatre Junction             60.375010
# 14            15  BTP044 - Sagar Theatre Junction             60.375010
# 15            16  BTP044 - Sagar Theatre Junction             60.375010
# 16            17             Area-12.933N-77.691E             44.262821
# 17            18   BTP051 - Safina Plaza Junction             35.646806
# 18            19   BTP051 - Safina Plaza Junction             35.646806
# 19            20   BTP051 - Safina Plaza Junction             35.646806
#
#     delay_score  vehicle_minutes_lost  person_minutes_lost  n_violations  \
# 0    31215500.0            31215500.0           46823250.0          5887
# 1    31215500.0            31215500.0           46823250.0          5887
# 2    31215500.0            31215500.0           46823250.0          5887
# 3    31215500.0            31215500.0           46823250.0          5887
# 4    31215500.0            31215500.0           46823250.0          5887
# 5    31215500.0            31215500.0           46823250.0          5887
# 6    31215500.0            31215500.0           46823250.0          5887
# 7    31215500.0            31215500.0           46823250.0          5887
# 8    31215500.0            31215500.0           46823250.0          5887
# 9    31215500.0            31215500.0           46823250.0          5887
# 10   31215500.0            31215500.0           46823250.0          5887
# 11    7536040.0             7536040.0           11304060.0         14615
# 12    7536040.0             7536040.0           11304060.0         14615
# 13    7536040.0             7536040.0           11304060.0         14615
# 14    7536040.0             7536040.0           11304060.0         14615
# 15    7536040.0             7536040.0           11304060.0         14615
# 16    9152200.0             9152200.0           13728300.0          4447
# 17   12486200.0            12486200.0           18729300.0            32
# 18   12486200.0            12486200.0           18729300.0            32
# 19   12486200.0            12486200.0           18729300.0            32
#
#      cii traffic_severity
# 0   79.6         CRITICAL
# 1   79.6         CRITICAL
# 2   79.6         CRITICAL
# 3   79.6         CRITICAL
# 4   79.6         CRITICAL
# 5   79.6         CRITICAL
# 6   79.6         CRITICAL
# 7   79.6         CRITICAL
# 8   79.6         CRITICAL
# 9   79.6         CRITICAL
# 10  79.6         CRITICAL
# 11  75.1         CRITICAL
# 12  75.1         CRITICAL
# 13  75.1         CRITICAL
# 14  75.1         CRITICAL
# 15  75.1         CRITICAL
# 16  62.4         CRITICAL
# 17  41.4         CRITICAL
# 18  41.4         CRITICAL
# 19  41.4         CRITICAL

# %%
summary = priority[[
    "traffic_rank",
    "junction_name",
    "traffic_impact_score",
    "traffic_severity"
]]

summary.head(10)
# Out:
#    traffic_rank                   junction_name  traffic_impact_score  \
# 0             1  BTP051 - Safina Plaza Junction             88.056107
# 1             2  BTP051 - Safina Plaza Junction             88.056107
# 2             3  BTP051 - Safina Plaza Junction             88.056107
# 3             4  BTP051 - Safina Plaza Junction             88.056107
# 4             5  BTP051 - Safina Plaza Junction             88.056107
# 5             6  BTP051 - Safina Plaza Junction             88.056107
# 6             7  BTP051 - Safina Plaza Junction             88.056107
# 7             8  BTP051 - Safina Plaza Junction             88.056107
# 8             9  BTP051 - Safina Plaza Junction             88.056107
# 9            10  BTP051 - Safina Plaza Junction             88.056107
#
#   traffic_severity
# 0         CRITICAL
# 1         CRITICAL
# 2         CRITICAL
# 3         CRITICAL
# 4         CRITICAL
# 5         CRITICAL
# 6         CRITICAL
# 7         CRITICAL
# 8         CRITICAL
# 9         CRITICAL

# %%
priority.columns
# Out:
# Index(['priority_rank', 'junction_name', 'n_violations', 'total_risk', 'cii',
#        'cii_tier', 'dominant_type', 'dominant_vehicle', 'dominant_station',
#        'lat', 'lon', 'h3_cell', 'total_overlap_risk', 'avg_active_violations',
#        'max_active_violations', 'avg_overlap_multiplier',
#        'max_overlap_multiplier', 'road_factor', 'congestion_weight',
#        'vehicle_weight', 'delay_score', 'congestion_intensity', 'delay_index',
#        'vehicle_minutes_lost', 'person_minutes_lost', 'person_hours_lost',
#        'congestion_cost_rs', 'traffic_severity', 'traffic_impact_score',
#        'traffic_rank'],
#       dtype='object')

# %%
top15 = (
    priority
    .sort_values("traffic_impact_score", ascending=False)
    .head(15)
)

plt.figure(figsize=(10,6))
plt.barh(
    top15["junction_name"],
    top15["traffic_impact_score"]
)
plt.xlabel("Traffic Impact Score")
plt.ylabel("Junction")
plt.title("Top 15 Congestion Hotspots")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(
    priority["delay_score"],
    bins=30
)
plt.xlabel("Delay Score")
plt.ylabel("Number of Junctions")
plt.title("Distribution of Traffic Delay Scores")
plt.show()

# %%
violation_delay = (
    priority
    .groupby("dominant_type")["delay_score"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(10,6))

violation_delay.plot(kind="bar")

plt.ylabel("Total Delay Score")
plt.title("Violations Contributing Most To Congestion")
plt.xticks(rotation=45)

plt.show()

# %%
severity_counts = (
    priority["traffic_severity"]
    .value_counts()
)

plt.figure(figsize=(7,7))

plt.pie(
    severity_counts,
    labels=severity_counts.index,
    autopct="%1.1f%%"
)

plt.title("Traffic Severity Distribution")

plt.show()

# %%
import folium
from folium.plugins import HeatMap

m = folium.Map(
    location=[
        priority["lat"].mean(),
        priority["lon"].mean()
    ],
    zoom_start=12
)

HeatMap(
    priority[
        ["lat","lon","delay_score"]
    ].values.tolist(),
    radius=18
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9169287aa40eb459fff9e6f7ad65277a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9169287aa40eb459fff9e6f7ad65277a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9169287aa40eb459fff9e6f7ad65277a = L.map(
#                 &quot;map_9169287aa40eb459fff9e6f7ad65277a&quot;,
#                 {
#                     center: [12.963901079393214, 77.58983991281904],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5226238376160d605ce59882ec71274e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5226238376160d605ce59882ec71274e.addTo(map_9169287aa40eb459fff9e6f7ad65277a);
#
#
#             var heat_map_3b2438a75613fa5ad72247de791d71b4 = L.heatLayer(
#                 [[12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.98190430301117, 77.60697523529039, 31215500.0], [12.972545289143795, 77.57742030273323, 7536040.0], [12.972545289143795, 77.57742030273323, 7536040.0], [12.972545289143795, 77.57742030273323, 7536040.0], [12.972545289143795, 77.57742030273323, 7536040.0], [12.972545289143795, 77.57742030273323, 7536040.0], [12.935341317512847, 77.6911620783783, 9152200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.987210546875, 77.619101171875, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [12.996736751501505, 77.61198218963963, 12486200.0], [13.004755042080212, 77.55141310747308, 3134720.0], [13.004755042080212, 77.55141310747308, 3134720.0], [13.004755042080212, 77.55141310747308, 3134720.0], [13.004755042080212, 77.55141310747308, 3134720.0], [13.004755042080212, 77.55141310747308, 3134720.0], [13.004755042080212, 77.55141310747308, 3134720.0], [13.004755042080212, 77.55141310747308, 3134720.0], [13.000229429032258, 77.57124373880318, 4189040.0], [13.000229429032258, 77.57124373880318, 4189040.0], [13.000229429032258, 77.57124373880318, 4189040.0], [13.000229429032258, 77.57124373880318, 4189040.0], [13.000229429032258, 77.57124373880318, 4189040.0], [13.000229429032258, 77.57124373880318, 4189040.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [12.992315599392974, 77.588865757952, 5628640.0], [13.185251428192682, 77.6800619298357, 3563160.0], [12.989055514993089, 77.55270291377282, 4189040.0], [12.989055514993089, 77.55270291377282, 4189040.0], [12.989055514993089, 77.55270291377282, 4189040.0], [12.989055514993089, 77.55270291377282, 4189040.0], [12.989055514993089, 77.55270291377282, 4189040.0], [12.989055514993089, 77.55270291377282, 41

# %%
set(priority["junction_name"]) - set(overlap_stats["junction_name"])
# Out:
# set()

# %%
pareto = (
    priority
    .sort_values("delay_score", ascending=False)
)

pareto["cum_pct"] = (
    pareto["delay_score"].cumsum()
    / pareto["delay_score"].sum()
) * 100

plt.figure(figsize=(10,5))

plt.plot(
    range(len(pareto)),
    pareto["cum_pct"]
)

plt.axhline(
    80,
    linestyle="--"
)

plt.ylabel("Cumulative % Delay")
plt.xlabel("Ranked Junctions")

plt.title("Pareto Analysis of Congestion")

plt.show()

# %%
OUTPUT_DIR = Path(".")

# hexdf.to_csv(OUTPUT_DIR / "h3_hexagons_with_cost.csv", index=False)
priority.to_csv(OUTPUT_DIR / "enforcement_ranking_with_cost.csv", index=False)
